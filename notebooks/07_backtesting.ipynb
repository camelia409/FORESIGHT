# %% [markdown]
# # Project FORESIGHT
# ## 07 - Rolling-Origin Backtesting & Model Selection
#
# **Intended Purpose**: Perform expanding/rolling-window backtesting across multiple origins to evaluate WAPE, bias, and stability before production selection.
#
# > *Note: Placeholder notebook created during project skeleton setup. Model training and destructive preprocessing are deferred until data governance decisions are finalized.*

# %%
# Placeholder setup cell
import sys
from pathlib import Path
# Add project root to sys.path
PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
