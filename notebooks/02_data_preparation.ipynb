# %% [markdown]
# # Project FORESIGHT
# ## 02 - Data Preparation & Cleaning
#
# **Intended Purpose**: Cleaning, resolving approved business decisions (e.g. 150 orphan inventory SKUs, 16 negative-margin SKUs), and integrating sources into analysis-ready daily/weekly tables.
#
# > *Note: Placeholder notebook created during project skeleton setup. Model training and destructive preprocessing are deferred until data governance decisions are finalized.*

# %%
# Placeholder setup cell
import sys
from pathlib import Path
# Add project root to sys.path
PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
